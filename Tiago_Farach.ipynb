# %% [markdown]
# # [EXERCISE 1]
#
# Full name: Tiago Nasif Farach
#
# University email: tnfarach@mail.austral.edu.ar
#
# ![descarga.jpeg](attachment:1fed0211-9813-4a63-b358-37caaeb42a71.jpeg)
#
# In this picture we can see a one of the best figures of argentinian rock. His name´s Carlos Alberto Solari "El Indio Solari"

# %% [markdown]
# # [EXERCISE 2]

# %%
#[EXERCISE 2]

width = 2
height = 3
rectangle_area = width*height

print(rectangle_area)
# Out:
# 6

# %% [markdown]
# # [EXERCISE 5]

# %%
a = 3
b = 7

# %% [markdown]
# Sum

# %%
print(a+b)
# Out:
# 10

# %% [markdown]
# Subtraction

# %%
print(a-b)
# Out:
# -4

# %% [markdown]
# Multiplication

# %%
print(a*b)
# Out:
# 21

# %% [markdown]
# Division

# %%
print(a/b)
# Out:
# 0.42857142857142855
